# %% [markdown]
# # Problem 2

# %%
from numpy.linalg import eig
from numpy.random import multivariate_normal as MVN
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem 2A

# %%
m1 = [[1, 0],
      [0, 1]]
values, vectors = eig(m1)
print("Eigenvalues:", values)
print("Eigenvectors:", vectors)
ratios = [values[0] / sum(values), values[1] / sum(values)]
print("Ratios of explained variance:", ratios)
# Out:
# Eigenvalues: [1. 1.]
# Eigenvectors: [[1. 0.]
#  [0. 1.]]
# Ratios of explained variance: [0.5, 0.5]

# %%
m2 = [[1, 0.5],
      [0.5, 1]]
values, vectors = eig(m2)
print("Eigenvalues:", values)
print("Eigenvectors:", vectors)
ratios = [values[0] / sum(values), values[1] / sum(values)]
print("Ratios of explained variance:", ratios)
# Out:
# Eigenvalues: [1.5 0.5]
# Eigenvectors: [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
# Ratios of explained variance: [0.75, 0.25000000000000006]

# %%
m3 = [[1, 0.9],
      [0.9, 1]]
values, vectors = eig(m3)
print("Eigenvalues:", values)
print("Eigenvectors:", vectors)
ratios = [values[0] / sum(values), values[1] / sum(values)]
print("Ratios of explained variance:", ratios)
# Out:
# Eigenvalues: [1.9 0.1]
# Eigenvectors: [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
# Ratios of explained variance: [0.9500000000000002, 0.04999999999999989]

# %%
pca = PCA(n_components=2)
i = 0
for m in [m1, m2, m3]:
    i += 1
    dist = MVN((1, 1), m, 1000)
    plt.figure()
    plt.scatter(dist[:, 0], dist1[:, 1])
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.title(f'm{i}')
    principalComponents = pca.fit(dist)
    print("Explained variance ratios:", pca.explained_variance_ratio_)
    print("Singular values: ", pca.singular_values_)
# Out:
# Explained variance ratios: [0.50821305 0.49178695]
# Singular values:  [32.25039273 31.72492508]
# Explained variance ratios: [0.74517263 0.25482737]
# Singular values:  [38.86690578 22.72869788]
# Explained variance ratios: [0.95086063 0.04913937]
# Singular values:  [45.58922089 10.36378841]
