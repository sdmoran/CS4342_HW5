# %% [markdown]
# # Problem 1: Gradient Descent, Linear Regression and Logistic Regression

# %%
from scipy.io import loadmat
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# This is the data part of the .mat file
f = loadmat('data_hw5_1.mat')['R']

# PCA
pca = PCA(n_components=3)
principalComponents = pca.fit(f)

print(pca.explained_variance_ratio_)
print(pca.singular_values_)

plt.figure()
plt.title("X1 vs X2")
plt.xlabel("X1")
plt.ylabel("X2")
plt.scatter(f[:, 0], f[:, 1])

plt.figure()
plt.title("X2 vs X3")
plt.xlabel("X2")
plt.ylabel("X3")
plt.scatter(f[:, 1], f[:, 2])

plt.figure()
plt.title("X1 vs X3")
plt.xlabel("X1")
plt.ylabel("X3")
plt.scatter(f[:, 0], f[:, 2])
# Out:
# [0.96536849 0.03267833 0.00195318]
# [168.59312184  31.0186745    7.58339912]
